# %% [markdown]
# # Requirements -  EditNotes

# %%
import os

# %%
import os

def replace_brackets_in_markdown(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".md"):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()

                updated_content = content.replace('[[-', '[[concept-')
                if content != updated_content:
                    with open(file_path, 'w', encoding='utf-8') as f:
                        f.write(updated_content)
                    print(f"Updated: {file_path}")

directory_to_scan = r"C:\Users\nonak\Documents\Thoughts\Atlas\02_CONCEPT"
replace_brackets_in_markdown(directory_to_scan)
# Out:
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\02_CONCEPT\concept-basico-de-estatistica.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\02_CONCEPT\concept-boxplot.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\02_CONCEPT\concept-cms-conceitos-basicos.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\02_CONCEPT\concept-cms-tipos.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\02_CONCEPT\concept-computacao-em-nuvem-historia.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\02_CONCEPT\concept-correlation-with-datetime.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\02_CONCEPT\concept-csm-partes-principais.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\02_CONCEPT\concept-csm-vantagens.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\02_CONCEPT\concept-estatistica-media-mediana-moda.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\02_CONCEPT\concept-fundamentos-cloud-computing.md
# ...

# %%
import os
import re
from pathlib import Path

def update_markdown_links(directory, prefix):
    """
    Atualiza links internos em arquivos markdown para incluir um prefixo.
    
    Parâmetros:
        directory (str): Caminho para o diretório com os arquivos markdown
        prefix (str): Prefixo a ser adicionado aos links internos
    """
    # Primeiro, coletamos todos os arquivos markdown existentes (com prefixo)
    existing_files = set()
    for filename in os.listdir(directory):
        if filename.endswith('.md'):
            # Armazenamos o nome sem .md e sem o prefixo (para comparação)
            basename = filename[:-3]
            if basename.startswith(prefix):
                original_basename = basename[len(prefix):]
                existing_files.add(original_basename)
    
    # Percorremos todos os arquivos para atualizar os links
    for filename in os.listdir(directory):
        if filename.endswith('.md'):
            filepath = os.path.join(directory, filename)
            
            with open(filepath, 'r', encoding='utf-8') as f:
                content = f.read()
            
            # Função para substituição dos links
            def replace_link(match):
                link_text = match.group(1)
                # Verificar se o link corresponde a um arquivo existente (sem prefixo)
                if link_text in existing_files:
                    return f"[[{prefix}{link_text}]]"
                return match.group(0)
            
            # Aplicar a substituição
            new_content = re.sub(r'\[\[([^\]]+)\]\]', replace_link, content)
            
            # Escrever de volta apenas se houve mudanças
            if new_content != content:
                with open(filepath, 'w', encoding='utf-8') as f:
                    f.write(new_content)
                print(f"Links atualizados em: {filename}")

# Exemplo de uso:
directory_path = "/caminho/para/sua/pasta"  # Substitua pelo caminho real
prefix_to_add = "concept-"
update_markdown_links(directory_path, prefix_to_add)
# Out:
# Renamed: 1.1-elementos-do-sistema-computacional-nonakaval.md -> concept-aoc-1.1-elementos-do-sistema-computacional-nonakaval.md
# Renamed: 1.1-elementos-do-sistema-computacional.md -> concept-aoc-1.1-elementos-do-sistema-computacional.md
# Renamed: 1.10-organizacao-da-memoria-principal.md -> concept-aoc-1.10-organizacao-da-memoria-principal.md
# Renamed: 1.11-memoria-rom.md -> concept-aoc-1.11-memoria-rom.md
# Renamed: 1.12-memoria-secundaria.md -> concept-aoc-1.12-memoria-secundaria.md
# Renamed: 1.13-organizacao-do-processador.md -> concept-aoc-1.13-organizacao-do-processador.md
# Renamed: 1.14-unidade-logica-e-aritmetica-(ula).md -> concept-aoc-1.14-unidade-logica-e-aritmetica-(ula).md
# Renamed: 1.15-unidade-funcional-de-controle.md -> concept-aoc-1.15-unidade-funcional-de-controle.md
# Renamed: 1.16-(rdm)-(rem).md -> concept-aoc-1.16-(rdm)-(rem).md
# Renamed: 1.17-(ci)---(ri).md -> concept-aoc-1.17-(ci)---(ri).md
# ...

# %% [markdown]
# ## Remover algum texto específico de **TODAS** as notas de uma pasta

# %%
import os
# Remover um texto específico de arquivos Markdown
def remove_text_from_markdown(directory, target_text):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".md"):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()

                updated_content = content.replace(target_text, '')
                if content != updated_content:
                    with open(file_path, 'w', encoding='utf-8') as f:
                        f.write(updated_content)
                    print(f"Updated: {file_path}")

directory_to_scan = r"C:\Users\nonak\Documents\Thoughts\System\cssSnippets"
target_text_to_remove = "↪[_cssSnippetCollection](_cssSnippetCollection.md)"

remove_text_from_markdown(directory_to_scan, target_text_to_remove)
# Out:
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Accented settings side headings.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Author callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Banner.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Bigger first letter.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Blockquote styling 01.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Blockquote styling 02.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Blockquote styling 03.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Calendar styling.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout icon to the top right corner.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - 3 callouts.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Callout without icon.md
# ...

# %% [markdown]
# ## Reescrever as propriedades de **TODAS** as notas de uma pasta

# %%
import os

# %%
# Remover e refazer cabeçalho em arquivos Markdown
def clean_and_update_markdown_notes(directory, new_header):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".md"):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()

                if content.startswith("---"):
                    end_of_header = content.find("---", 3)
                    if end_of_header != -1:
                        content = content[end_of_header + 3:].lstrip()

                updated_content = new_header + "\n" + content

                with open(file_path, 'w', encoding='utf-8') as f:
                    f.write(updated_content)
                print(f"Updated: {file_path}")

directory_to_scan = r"C:\Users\nonak\Documents\Thoughts\Atlas\00_DRAFT"
new_header = """---
tags:
  - learning
  - concept
HUB:
  - "[[hub-python]]"
---"""

clean_and_update_markdown_notes(directory_to_scan, new_header)
# Out:
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\00_DRAFT\concept-python-date(datas)-Accessing Datetime Components.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\00_DRAFT\concept-python-date(datas)-Basic Date Creation.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\00_DRAFT\concept-python-date(datas)-Calculating Date Differences.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\00_DRAFT\concept-python-date(datas)-Creating Datetime Objects.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\00_DRAFT\concept-python-date(datas)-Custom Date Formatting.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\00_DRAFT\concept-python-date(datas)-Date Arithmetic with timedelta.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\00_DRAFT\concept-python-date(datas)-ISO 8601 Standard Formatting.md
# Updated: C:\Users\nonak\Documents\Thoughts\Atlas\00_DRAFT\concept-python-date(datas)-Key Concepts and Best Practices.md
# ...
