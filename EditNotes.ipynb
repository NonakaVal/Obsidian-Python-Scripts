# %% [markdown]
# # Requirements -  EditNotes

# %% [markdown]
# ## Remover algum texto específico de **TODAS** as notas de uma pasta

# %%
import os

def confirm_action(prompt: str) -> bool:
    """Solicita confirmação do usuário."""
    response = input(f"{prompt} (digite 'CONFIRMAR' para prosseguir): ").strip()
    return response.upper() == "CONFIRMAR"

def remove_text_from_markdown(directory: str, target_text: str) -> None:
    """
    Remove um texto específico de arquivos Markdown com verificações de segurança.
    
    Args:
        directory: Diretório para procurar arquivos .md
        target_text: Texto a ser removido dos arquivos
    """
    # Verificação 1: Confirmar o diretório
    print(f"\nDiretório a ser analisado: {directory}")
    dir_confirm = input("Digite parte do caminho para confirmar: ").strip()
    
    if dir_confirm not in directory:
        print("Verificação do diretório falhou. Operação cancelada.")
        return
    
    # Verificação 2: Confirmar o texto a ser removido
    print(f"\nTexto a ser removido: '{target_text}'")
    if not confirm_action("Confirmar remoção deste texto?"):
        print("Operação cancelada pelo usuário.")
        return
    
    print("\nIniciando processamento...")
    files_updated = 0
    
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".md"):
                file_path = os.path.join(root, file)
                try:
                    with open(file_path, 'r', encoding='utf-8') as f:
                        content = f.read()
                    
                    # Verifica se o texto está presente
                    if target_text not in content:
                        continue
                        
                    # Remove o texto
                    updated_content = content.replace(target_text, '')
                    
                    # Verifica se houve alteração
                    if content != updated_content:
                        # Cria backup antes de modificar
                        backup_path = file_path + '.bak'
                        with open(backup_path, 'w', encoding='utf-8') as f:
                            f.write(content)
                        
                        # Salva as alterações
                        with open(file_path, 'w', encoding='utf-8') as f:
                            f.write(updated_content)
                        
                        files_updated += 1
                        print(f"✓ Atualizado: {file_path} (backup em {backup_path})")
                
                except PermissionError:
                    print(f"! Permissão negada: {file_path}")
                except Exception as e:
                    print(f"! Erro ao processar {file_path}: {str(e)}")
    
    print(f"\nOperação concluída! {files_updated} arquivos foram modificados.")

if __name__ == "__main__":
    # Configurações
    directory_to_scan = r"C:\Users\nonak\Documents\Thoughts\System\cssSnippets"
    target_text_to_remove = "↪[_cssSnippetCollection](_cssSnippetCollection.md)"
    
    # Executa a função principal
    remove_text_from_markdown(directory_to_scan, target_text_to_remove)
# Out:
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Accented settings side headings.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Author callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Banner.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Bigger first letter.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Blockquote styling 01.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Blockquote styling 02.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Blockquote styling 03.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Calendar styling.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout icon to the top right corner.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - 3 callouts.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Callout without icon.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Celtic callout border.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Folder structure callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Gummy callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Label callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Leader list callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Minimal callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Old callouts.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Outlined callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Power callouts.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Quote callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Scroller callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Sleek callout (AnuPpuccin theme).md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Tabbed callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Theorem callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Timeline callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling - Wikipedia like infobox.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout Styling 01 - Prism theme callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Callout styling 02.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Canvas styling - Gradient canvas cards.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Card layout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Card view.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Celtic inline title styling.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Checkboxes - AnuPpuccin theme.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Checkboxes - Minimal theme.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Checkboxes - Origami theme.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Checkboxes - Priority checkboxes.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Checkboxes - Progress bar checkboxes.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Checkboxes - SlRvb's checkboxes (ITS theme).md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Code block styling 01.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Code block styling 02.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Collapsible image caption callout.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Coloured ribbon.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Coloured tab header container.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Colourful headings underline and divider.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Command palette styling 01.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Command palette styling 02.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Compact tabs.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Empty tab styling.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Equally spaced dataview columns.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\External link styling 01.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Faded emoji in tasks.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\File explorer styling - Folder description.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\File explorer styling - Folder headers.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\File explorer styling - Rainbow folder background.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\File explorer styling - Rainbow folder titles.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Gradient Colored Icon Tabs.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Heading indicators 01.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Heading indicators 02.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Hide ribbon on collapse.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Hide titlebar buttons and freeze the right-sidedock toggle button position.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Hide window button panel.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Icon before headings.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Image as a background 01.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Image as a background 02.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Image description when hover.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Image gallery.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Image grid.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Image styling - Zoom image.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Image tweak.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Kanban styling - background based on tag.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Kanban styling - background customized.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Kanban styling - Notion like Kanban board.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Left aligned note header.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Link styling 01.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Loading screen tweak.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Multicolumn note.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\New note button.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Note icon.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Outline numbering.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Pinned tab styling.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Popover border.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Progress bar styling.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Properties into two columns.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Properties on hover.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Safari tabs.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Show note header on hover.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Sidenote callout 01.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Sidenote callout 02.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Spoiler text.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Table styling - Centred table.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Table styling - Left column header.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Table styling - Rounded corners.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Tabs styling - Square tabs.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Tabs styling - Stacked tabbed minimal tweak.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Tag styling - Hide hash symbol.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Tag styling 01.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Tags styling - Rainbow tags.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Tags styling - Target specific tag.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Tooltip styling.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Unordered list styling 01.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Unordered list styling 02.md
# Updated: C:\Users\nonak\Documents\Thoughts\System\cssSnippets\Vertical label arrangement.md

# %% [markdown]
# ## Reescrever as propriedades de **TODAS** as notas de uma pasta

# %%
import os

def confirmar_acao(mensagem: str) -> bool:
    """Solicita confirmação do usuário para uma ação."""
    resposta = input(f"{mensagem} (digite 'confirmar' para prosseguir): ").strip().lower()
    return resposta == "confirmar"

def clean_and_update_markdown_notes(directory: str, new_header: str) -> None:
    """Remove e refaz o cabeçalho em arquivos Markdown com confirmações."""
    # Etapa 1: Confirmação do diretório
    print(f"\nDiretório a ser modificado: {directory}")
    caminho_digitado = input("Digite novamente o caminho ou parte dele para confirmar: ").strip()
    
    if caminho_digitado not in directory:
        print("Verificação do caminho falhou. Operação cancelada.")
        return
    
    # Etapa 2: Confirmação final
    if not confirmar_acao(f"\nVocê está prestes a modificar todos os arquivos .md em '{directory}'"):
        print("Operação cancelada pelo usuário.")
        return
    
    print("\nIniciando processamento...")
    
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".md"):
                file_path = os.path.join(root, file)
                try:
                    with open(file_path, 'r', encoding='utf-8') as f:
                        content = f.read()

                    # Remove frontmatter existente
                    if content.startswith("---"):
                        end_of_header = content.find("---", 3)
                        if end_of_header != -1:
                            content = content[end_of_header + 3:].lstrip()

                    # Adiciona novo header
                    updated_content = new_header + "\n" + content

                    with open(file_path, 'w', encoding='utf-8') as f:
                        f.write(updated_content)
                    print(f"✓ Atualizado: {file_path}")
                
                except Exception as e:
                    print(f"! Erro ao processar {file_path}: {str(e)}")
    
    print("\nOperação concluída!")

if __name__ == "__main__":
    directory_to_scan = r"C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets"
    new_header = """---
tags:
  - cssSnippetCollection 
HUB:
  - "[[hub-css]]"
---"""
    
    clean_and_update_markdown_notes(directory_to_scan, new_header)
# Out:
# Diretório a ser modificado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets
# Digite novamente o caminho ou parte dele para confirmar:  C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets
#
# Você está prestes a modificar todos os arquivos .md em 'C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets' (digite 'confirmar' para prosseguir):  confirmar
# Iniciando processamento...
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Accented settings side headings.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Author callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Banner.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Bigger first letter.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Blockquote styling 01.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Blockquote styling 02.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Blockquote styling 03.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Calendar styling.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout icon to the top right corner.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - 3 callouts.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Callout without icon.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Celtic callout border.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Folder structure callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Gummy callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Label callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Leader list callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Minimal callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Old callouts.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Outlined callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Power callouts.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Quote callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Scroller callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Sleek callout (AnuPpuccin theme).md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Tabbed callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Theorem callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Timeline callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling - Wikipedia like infobox.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout Styling 01 - Prism theme callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Callout styling 02.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Canvas styling - Gradient canvas cards.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Card layout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Card view.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Celtic inline title styling.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Checkboxes - AnuPpuccin theme.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Checkboxes - Minimal theme.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Checkboxes - Origami theme.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Checkboxes - Priority checkboxes.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Checkboxes - Progress bar checkboxes.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Checkboxes - SlRvb's checkboxes (ITS theme).md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Code block styling 01.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Code block styling 02.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Collapsible image caption callout.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Coloured ribbon.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Coloured tab header container.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Colourful headings underline and divider.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Command palette styling 01.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Command palette styling 02.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Compact tabs.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Empty Tab Styling 02.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Empty tab styling.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Equally spaced dataview columns.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\External link styling 01.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Faded emoji in tasks.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\File explorer styling - Folder description.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\File explorer styling - Folder headers.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\File explorer styling - Rainbow folder background.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\File explorer styling - Rainbow folder titles.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Gradient Colored Icon Tabs.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Heading indicators 01.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Heading indicators 02.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Hide ribbon on collapse.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Hide titlebar buttons and freeze the right-sidedock toggle button position.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Hide window button panel.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Icon before headings.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Image as a background 01.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Image as a background 02.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Image description when hover.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Image gallery.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Image grid.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Image styling - Zoom image.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Image tweak.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Kanban styling - background based on tag.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Kanban styling - background customized.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Kanban styling - Notion like Kanban board.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Left aligned note header.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Link styling 01.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Loading screen tweak.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Multicolumn note.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\New note button.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Note icon.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Outline numbering.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Pinned tab styling.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Popover border.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Progress bar styling.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Properties into two columns.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Properties on hover.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Safari tabs.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Show note header on hover.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Sidenote callout 01.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Sidenote callout 02.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Spoiler text.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Table styling - Centred table.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Table styling - Left column header.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Table styling - Rounded corners.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Tabs styling - Square tabs.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Tabs styling - Stacked tabbed minimal tweak.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Tag styling - Hide hash symbol.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Tag styling 01.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Tags styling - Rainbow tags.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Tags styling - Target specific tag.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Tooltip styling.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Unordered list styling 01.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Unordered list styling 02.md
# ✓ Atualizado: C:\Users\desktop\Documents\Thoughts\System\ASSETS\cssSnippets\Vertical label arrangement.md
#
# Operação concluída!
