# %%
import os
import re

CAMINHO_PASTA = r"C:\Users\nonak\Downloads\test-vaut\System\index" # <- ajuste seu caminho aqui

def sanitizar_nome_arquivo(nome):
    return re.sub(r'[\\/#%&{}<>*?$\'":@]', '', nome).strip()

def extrair_secoes(conteudo):
    # Encontra todas as seções iniciadas com ### até o próximo ### ou fim do texto
    padrao = r"(####### .+?)(?=\n####### |\Z)"
    secoes = re.findall(padrao, conteudo, flags=re.DOTALL)
    return secoes

def processar_arquivo(caminho):
    with open(caminho, 'r', encoding='utf-8') as f:
        conteudo = f.read()

    secoes = extrair_secoes(conteudo)
    if not secoes:
        return

    novo_conteudo = conteudo
    pasta_destino = os.path.dirname(caminho)  # ← Agora salva na mesma pasta da nota principal

    for secao in secoes:
        linha_header = secao.splitlines()[0]
        titulo = linha_header.replace("#######", "").strip()
        nome_arquivo = sanitizar_nome_arquivo(titulo) + ".md"
        caminho_novo = os.path.join(pasta_destino, nome_arquivo)

        # Cria nova nota
        with open(caminho_novo, 'w', encoding='utf-8') as f_out:
            f_out.write(secao.strip())

        # Substitui no conteúdo original
        novo_conteudo = novo_conteudo.replace(secao.strip(), f"![[{titulo}]]")

        print(f"✅ Criado: {caminho_novo}")

    # Atualiza a nota base
    with open(caminho, 'w', encoding='utf-8') as f:
        f.write(novo_conteudo)
    print(f"📝 Atualizado: {caminho}")


def processar_todos(caminho_base):
    for raiz, _, arquivos in os.walk(caminho_base):
        for arquivo in arquivos:
            if arquivo.endswith(".md"):
                caminho_completo = os.path.join(raiz, arquivo)
                print(f"\n📄 Processando: {caminho_completo}")
                processar_arquivo(caminho_completo)

if __name__ == "__main__":
    processar_todos(CAMINHO_PASTA)
# Out:
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\00_DRAFT.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\01_INDEX.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\02_CONCEPT.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\03_SNIPPETS.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\04_COMPONENT.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\05_DOC.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\06_WORKFLOW.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\07_RESOURCES.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\08_MAPS.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\1-fundamentos-do-marketing.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\1-modulo.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\2-modulo.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\2-redes-sociais.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\3-modulo.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\4-modulo.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\5-modulo.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\AOC.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\ARCHIVES.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\AREAS.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\ASSETS.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Atlas.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\bbHarry.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Calendar.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Chapters.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\characters.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\collectors-notes.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\collectors-tutorials.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\collectorsGuardian.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\cssSnippets.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\DAILY.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Dataview.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\definitions.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Dev.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Drafts.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\ebooks.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\ECT.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Efforts.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\eng. software.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Entertainment.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\FirstVault.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\FORMAT.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\franvce.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\GCTI.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\HarryLearning.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\HTML.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\HUB.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\index.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\index_notas.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\knowledge.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\livro 1.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\LLM-searches.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\marketing.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Mentorias.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\MEUS-INFOS.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\modulos-start.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\MONTHLY.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\MUSIC.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\neurociência.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\outbound-marketing.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Pastas.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\PEOPLE.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\pkm-videos.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\PKM-Youtube-Videos.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\professional-career.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Saúde e bem estar.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\SO.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\social-media-project.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Social.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\System.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\TEMPLATE.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\test.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Thinking.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\VaultSnippets.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\von.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\webdesign.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\Writing.md
#
# 📄 Processando: C:\Users\nonak\Downloads\test-vaut\System\index\YEARLY.md
