# %%
import os
from collections import defaultdict, Counter

def extract_values_and_notes(directory, target_property="HUB"):
    property_to_notes = defaultdict(list)

    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".md"):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()

                if content.startswith("---"):
                    end_of_header = content.find("---", 3)
                    if end_of_header != -1:
                        header = content[3:end_of_header].strip()
                        inside_property = False
                        for line in header.splitlines():
                            line = line.strip()
                            if line.startswith(f"{target_property}:"):
                                inside_property = True
                            elif inside_property:
                                if line.startswith("-"):
                                    property_value = line.strip("- ").strip()
                                    property_to_notes[property_value].append(file)
                                elif not line or line.startswith("#"):
                                    inside_property = False
    return property_to_notes

def count_unique_values(property_to_notes):
    return {prop: len(notes) for prop, notes in property_to_notes.items()}

def extract_header_values_from_markdown(directory):
    header_values = defaultdict(list)

    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".md"):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()

                if content.startswith("---"):
                    end_of_header = content.find("---", 3)
                    if end_of_header != -1:
                        header = content[3:end_of_header].strip()
                        current_key = None
                        for line in header.splitlines():
                            line = line.strip()
                            if ":" in line:
                                key, value = map(str.strip, line.split(":", 1))
                                current_key = key
                                if value:
                                    header_values[key].append(value)
                            elif line.startswith("-") and current_key:
                                value = line.strip("- ").strip()
                                header_values[current_key].append(value)
    return header_values

def count_all_unique_values(header_values):
    return {key: Counter(values) for key, values in header_values.items()}


# Caminho para os arquivos Markdown
directory_to_scan = r"C:\Users\nonak\Documents\Thoughts"

# Processamento da propriedade 'HUB'
property_to_notes = extract_values_and_notes(directory_to_scan, target_property="HUB")
unique_property_counts = count_unique_values(property_to_notes)

# Exibir valores únicos da propriedade 'HUB'
print("Contagem de valores únicos da propriedade 'HUB':")
for prop, count in sorted(unique_property_counts.items(), key=lambda item: item[1], reverse=True):
    print(f"{prop}: {count}")

total_hub = sum(unique_property_counts.values())
print(f"\nTotal geral de arquivos associados a valores 'HUB': {total_hub}")

print("\n -------------------------------------------------------------------------------- \n")

# Análise geral de propriedades
header_values = extract_header_values_from_markdown(directory_to_scan)
unique_value_counts = count_all_unique_values(header_values)

print("\nContagem de valores únicos por propriedade (ordenado por contagem):")
for key, counter in unique_value_counts.items():
    print(f"\nPropriedade: {key}")
    for value, count in sorted(counter.items(), key=lambda item: item[1], reverse=True):
        print(f"  {value}: {count}")
    total_prop = sum(counter.values())
    print(f"  >> Total: {total_prop}")
# Out:
# Contagem de valores únicos da propriedade 'HUB':
# "[[hub-python]]": 250
# "[[hub-collectors]]": 196
# "[[hub-aoc]]": 107
# "[[hub-statistic]]": 80
# "[[hub-mkt]]": 73
# "[[hub-SistemaOperacional]]": 73
# "[[hub-tratamento-de-dados]]": 71
# "[[hub-data-visualization]]": 50
# "[[hub-ect]]": 34
# "[[hub-probabilidade]]": 30
# "[[hub-social-midia]]": 30
# "[[hub-copy]]": 27
# "[[hub-math]]": 27
# "[[hub-ml-models]]": 26
# "[[hub-tec]]": 23
# "[[hub-logic]]": 21
# "[[hub-growth]]": 21
# "[[hub-hypothesis-testing]]": 19
# "[[hub-descriptive-analysis]]": 19
# "[[hub-sql]]": 17
# "[[hub-writing]]": 17
# "[[hub-GCTI]]": 16
# "[[hub-pkm]]": 12
# "[[hub-design]]": 7
# "[[hub-thinking]]": 7
# "[[hub-bi]]": 6
# learning/review: 6
# "[[hub-psyche]]": 4
# "[[hub-music]]": 4
# learning: 3
# "[[]]": 3
# "[[hub-filosofia]]": 2
# "[[hub-git]]": 2
# hip-hop: 2
# "[[hub-llm]]": 1
# data-types: 1
# "[[hub-work]]": 1
# "[[hub-so]]": 1
# "[[hub-prompts]]": 1
# "[[Efforts/AREAS/bbHarry/AprendizadoDobb.md|AprendizadoDobb]]": 1
# dashboard: 1
# wide-page: 1
# thinking: 1
# tocomplete: 1
# Art rock: 1
# psychedelic rock: 1
# lounge pop: 1
# space pop: 1
# glam roc: 1
# "[[hub-reading]]": 1
# hide-properties_editing: 1
# hide-properties_reading: 1
#
# Total geral de arquivos associados a valores 'HUB': 1303
#
#  --------------------------------------------------------------------------------
#
#
# Contagem de valores únicos por propriedade (ordenado por contagem):
#
# Propriedade: cssclasses
#   hide-properties_reading: 88
#   hide-properties_editing: 88
#   dashboard: 10
#   dash: 9
#   wide-page: 6
#   []: 1
#   >> Total: 202
#
# Propriedade: tags
#   learning: 597
#   oldVoult: 227
#   work: 188
#   learning/review: 117
#   calendar/daily: 90
#   resources: 68
#   lab: 50
#   learning/book: 21
#   reading: 15
#   tocomplete/explicar: 13
#   tocomplete: 13
#   learning/artigo: 8
#   thinking: 8
#   tocomplete/refatorar: 7
#   new_note: 7
#   people: 7
#   tocomplete/atomizar: 6
#   walkthrough: 6
#   area/bbharry: 5
#   aboutMe: 5
#   scisync: 4
#   []: 3
#   effort: 3
#   dataview: 3
#   calendar/year: 2
#   area/pkm-youtube-videos/acexpara-method-video: 2
#   area/pkm-videos: 2
#   workstation_note: 2
#   calendar/month: 1
#   fleeting_note: 1
#   area/pkm-youtube-videos/ecological-thinking-video: 1
#   area/pkm-youtube-videos/pkm-introduction-video: 1
#   area/pkm-youtube-videos/plugins-obrigatorio-video: 1
#   area/harrylearning: 1
#   area/harrylearning/fundamentos_alfabetização: 1
#   area/pkm-youtube-videos/importancia-nota-diaria: 1
#   area/pkm-youtube-videos: 1
#   area/pkm-youtube-videos/serie-playlist-entendendo-pkm: 1
#   area/saúde_e_bem_estar: 1
#   area/saúde_e_bem_estar/rotina_de_treino: 1
#   area/bbHarry: 1
#   >> Total: 1492
#
# Propriedade: HUB
#   "[[hub-python]]": 250
#   "[[hub-collectors]]": 196
#   "[[hub-aoc]]": 107
#   "[[hub-statistic]]": 80
#   "[[hub-mkt]]": 73
#   "[[hub-SistemaOperacional]]": 73
#   "[[hub-tratamento-de-dados]]": 71
#   "[[hub-data-visualization]]": 50
#   "[[hub-ect]]": 34
#   "[[hub-probabilidade]]": 30
#   "[[hub-social-midia]]": 30
#   "[[hub-copy]]": 27
#   "[[hub-math]]": 27
#   "[[hub-ml-models]]": 26
#   "[[hub-tec]]": 23
#   "[[hub-logic]]": 21
#   "[[hub-growth]]": 21
#   "[[hub-hypothesis-testing]]": 19
#   "[[hub-descriptive-analysis]]": 19
#   "[[hub-sql]]": 17
#   "[[hub-writing]]": 17
#   "[[hub-GCTI]]": 16
#   "[[hub-pkm]]": 12
#   "[[hub-design]]": 7
#   "[[hub-thinking]]": 7
#   "[[hub-bi]]": 6
#   "[[hub-psyche]]": 4
#   "[[hub-music]]": 4
#   "[[]]": 3
#   "[[hub-filosofia]]": 2
#   "[[hub-git]]": 2
#   "[[hub-llm]]": 1
#   "[[hub-work]]": 1
#   "[[hub-so]]": 1
#   []: 1
#   "[[hub-prompts]]": 1
#   "[[hub-reading]]": 1
#   >> Total: 1280
#
# Propriedade: created
#   "[[30-01-2024]]": 14
#   "[[2025-04-27]]": 9
#   "[[2024-05-10]]": 8
#   "[[2024-03-20]]": 8
#   "[[2024-03-19]]": 7
#   "[[08-02-2024]]": 7
#   '[[<% tp.date.now("YYYY-MM-DD") %>]]': 7
#   "[[10-02-2024]]": 6
#   "[[2024-02-10]]": 6
#   "[[2024-03-24]]": 5
#   "[[2024-04-06]]": 5
#   "[[2024-05-07]]": 5
#   "[[2024-03-23]]": 5
#   "[[2024-03-18]]": 5
#   "[[2024-04-09]]": 5
#   "[[2024-05-15]]": 5
#   "[[07-02-2024]]": 5
#   "[[2024-03-13]]": 5
#   "[[2024-08-04]]": 5
#   "[[2024-03-21]]": 4
#   "[[2024-02-12]]": 4
#   "[[2024-06-09]]": 4
#   "[[21-01-2024]]": 3
#   "[[17-01-2024]]": 3
#   "[[2024-06-11]]": 3
#   '[[2025-04-27]]': 3
#   "[[2024-08-17]]": 2
#   "[[2024-05-08]]": 2
#   "[[31-01-2024]]": 2
#   2024-12-29 00:27: 2
#   '[[2024-12-28]]': 2
#   "[[2024-06-01]]": 1
#   "[[18-01-2024]]": 1
#   "[[2024-08-14]]": 1
#   "[[15-01-2024]]": 1
#   "[[2024-02-13]]": 1
#   "[[2024-03-09]]": 1
#   "[[2024-04-22]]": 1
#   "[[2024-02-23]]": 1
#   "[[2024-03-29]]": 1
#   "[[09-02-2024]]": 1
#   "[[2024-04-01]]": 1
#   "[[2024-03-07]]": 1
#   "[[2024-03-26]]": 1
#   "[[2024-04-27]]": 1
#   "[[2024-08-24]]": 1
#   2024-10-20 16:48: 1
#   2024-12-27 07:49: 1
#   2025-04-27 21:05: 1
#   2025-04-29 15:15: 1
#   '![[2025-04-29]]': 1
#   '[[2025-04-29]]': 1
#   2025-04-05 17:45: 1
#   2025-04-05 18:06: 1
#   2025-04-18 23:59: 1
#   "[[2025-04-29]]": 1
#   2024-12-29 00:25: 1
#   2024-12-29 00:28: 1
#   2024-12-29 00:30: 1
#   2025-02-05 03:14: 1
#   2025-02-05 03:23: 1
#   2025-03-11 22:32: 1
#   2024-12-29 00:24: 1
#   2024-12-29 03:24: 1
#   2025-02-19 20:55: 1
#   2025-02-19 20:59: 1
#   2025-02-08 17:07: 1
#   2025-02-08 17:05: 1
#   <% tp.file.creation_date()%>: 1
#   >> Total: 194
#
# Propriedade: hub
#   "[[hub-tec]]": 34
#   "[[hub-math]]": 17
#   "[[hub-sql]]": 5
#   "[[hub-python]]": 4
#   "[[hub-data-visualization]]": 1
#   "[[hub-social]]": 1
#   >> Total: 62
#
# Propriedade: origin
#   "[[book-introducao-estatistica-12edicao-mario-f-triola-2017]]": 20
#   https://blog.mettzer.com/coleta-de-dados/: 1
#   https://docs.pandas-ai.com/en/latest/: 1
#   https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html: 1
#   "[[plano-ensino-computer-science-anhanguera]]": 1
#   >> Total: 24
#
# Propriedade: link-to-lib
#   https://docs.streamlit.io/: 2
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.agg.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.at.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.concat.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.cut.html: 1
#   https://pandas.pydata.org/docs/reference/frame.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.factorize.html: 1
#   https://pandas.pydata.org/docs/reference/general_functions.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.get.html#pandas-dataframe-get: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.insert.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.isna.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.lt.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.items.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.__iter__.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iterrows.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.itertuples.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.map.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mask.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.melt.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.merge.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pipe.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.pivot.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.qcut.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rolling.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.select_dtypes.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.Series.html: 1
#   https://pandas.pydata.org/docs/reference/series.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_flags.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.unique.html: 1
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.xs.html: 1
#   https://docs.streamlit.io/develop/concepts/architecture/caching: 1
#   https://docs.streamlit.io/develop/concepts/architecture/forms: 1
#   https://docs.streamlit.io/develop/concepts/architecture/fragments: 1
#   >> Total: 43
#
# Propriedade: aliases
#   data-types: 1
#   >> Total: 1
#
# Propriedade: share_link
#   https://share.note.sx/owiue6fi#WjxRcjTEE2haloex7gbYao7nC6trOUvGtas4jmm5cXQ: 1
#   https://share.note.sx/lv7ez86u#tBmlTqoFysMg9ZVD5UPyFbUVA/kVeuXRgSzTneytgcc: 1
#   https://share.note.sx/8aus1rrs#FyVYHDZLgdfmDS+Ah/3gNqt+SsLthuwiREzNpU0n3mo: 1
#   https://share.note.sx/364j7fw7#ac/d8/iMHyXw9Ic9q/2Hclnh2YzlZURLup89ovOc+eE: 1
#   https://share.note.sx/vu6rkgo4#DD4NOlSVcHHdx0tHOkLmENC6lHb6tXv0hpGKJcznHNQ: 1
#   https://share.note.sx/i4v8brpi#HeeeX0A0RAyCBX8DorXPnGb8Ex5joiRL9kT81ffbnj4: 1
#   https://share.note.sx/46e9elwf#ZVpCu/+dlXL0UbFwGmySLK1reeNLnRwX034RLF8gi40: 1
#   https://share.note.sx/sh2avl83#6UoPzfEFVuXRmu0mqWkHFE0FQtfqXGHIS/MXVlP51jU: 1
#   https://share.note.sx/6mkh1qm4#wvYWp5qe9hWYFBIXUGKHU81oPfhYbSz7iVKGovXW77M: 1
#   >> Total: 9
#
# Propriedade: share_updated
#   2024-10-08T14:42:21-03:00: 1
#   2025-01-31T07:38:35-03:00: 1
#   2025-02-06T16:31:37-03:00: 1
#   2025-04-05T17:47:37-03:00: 1
#   2025-01-20T20:15:21-03:00: 1
#   2025-04-24T16:49:35-03:00: 1
#   2025-04-24T16:50:59-03:00: 1
#   2025-04-26T06:55:40-03:00: 1
#   2025-04-29T18:06:52-03:00: 1
#   >> Total: 9
#
# Propriedade: connections
#   "[[Efforts/AREAS/bbHarry/AprendizadoDobb.md|AprendizadoDobb]]": 4
#   "[[2. collectorsGuardian|2. collectorsGuardian]]": 2
#   "[[ZETA/LITERATURE/Curt Richter’s Drowning Rats Experiment (1957).md|Curt Richter’s Drowning Rats Experiment (1957)]]": 1
#   "[[Efforts/ARCHIVES/HarryLearning/fundamentos alfabetização.md|fundamentos alfabetização]]": 1
#   "[[Efforts/AREAS/bbHarry/Atividades-para-FAZER-com-bb.md|Atividades-para-FAZER-com-bb]]": 1
#   "[[Efforts/ARCHIVES/ecological-thinking-video.md|ecological-thinking-video]]": 1
#   "[[Efforts/ARCHIVES/pkm-introduction-video.md|pkm-introduction-video]]": 1
#   >> Total: 11
#
# Propriedade: type
#   area_note: 9
#   new_note: 8
#   area_family: 6
#   workstation_note: 2
#   fleeting_note: 1
#   permanent_note: 1
#   project: 1
#   >> Total: 28
#
# Propriedade: tag
#   calendar/daily: 80
#   >> Total: 80
#
# Propriedade: kanban-plugin
#   board: 1
#   >> Total: 1
#
# Propriedade: area
#   PKM-Youtube-Videos: 8
#   bbHarry: 4
#   HarryLearning: 2
#   Saúde e bem estar: 2
#   pkm-videos: 2
#   "[[bbHarry]]": 1
#   <% tp.file.folder()%>: 1
#   "[[<% tp.file.folder() %>]]": 1
#   >> Total: 21
#
# Propriedade: Status
#   In Progress: 3
#   Posted: 2
#   >> Total: 5
#
# Propriedade: board
#   reflexao: 8
#   conceito: 4
#   "": 2
#   resumo: 1
#   >> Total: 15
#
# Propriedade: area_category
#   content-creation: 2
#   family: 1
#   >> Total: 3
#
# Propriedade: summary
#   Sobre Alfabetização e aprendizado no geral: 1
#   Ideias do que fazer com o bb: 1
#   Histórias que quero ou vou contar ao bb: 1
#   Vídeo de resumo pkm: 1
#   Vídeos sobre conceitos iniciais, dicas básicas etc.: 1
#   >> Total: 5
#
# Propriedade: releaseDate
#   "[[year-2018]]": 2
#   "[[year-2024]]": 1
#   >> Total: 3
#
# Propriedade: genre
#   hip-hop: 2
#   Art rock: 1
#   psychedelic rock: 1
#   lounge pop: 1
#   space pop: 1
#   glam roc: 1
#   >> Total: 7
#
# Propriedade: artist
#   "[[Twenty One Pilots]]": 2
#   "[[Arctic Monkeys]]": 1
#   >> Total: 3
#
# Propriedade: length
#   47:14: 1
#   "\r40:51": 1
#   56:09: 1
#   >> Total: 3
#
# Propriedade: key
#   "+10": 1
#   >> Total: 1
#
# Propriedade: since
#   "2018": 1
#   >> Total: 1
#
# Propriedade: from
#   Guapiara - Piracicaba: 1
#   >> Total: 1
#
# Propriedade: last
#   2024-01-18: 1
#   >> Total: 1
#
# Propriedade: close-to
#   "[[1_ME]]": 1
#   >> Total: 1
#
# Propriedade: archetype
#   "[[mage]]": 1
#   >> Total: 1
#
# Propriedade: main-skills
#   +10int: 1
#   8socialskills: 1
#   >> Total: 2
#
# Propriedade: project
#   <% tp.file.folder()%>: 1
#   <% tp.file.folder() %>: 1
#   >> Total: 2
#
# Propriedade: goal
#   "": 1
#   >> Total: 1

# %%
import os

# %%
def buscar_arquivos_por_palavra(caminho_raiz, palavra_chave):
    caminhos_encontrados = []

    for raiz, _, arquivos in os.walk(caminho_raiz):
        for nome_arquivo in arquivos:
            caminho_completo = os.path.join(raiz, nome_arquivo)
            try:
                with open(caminho_completo, 'r', encoding='utf-8') as arquivo:
                    conteudo = arquivo.read()
                    if palavra_chave in conteudo:
                        caminhos_encontrados.append(caminho_completo)
            except (UnicodeDecodeError, PermissionError, FileNotFoundError):
                # Ignora arquivos que não podem ser lidos como texto
                continue

    return caminhos_encontrados

# Exemplo de uso
if __name__ == "__main__":
    caminho = input("Digite o caminho do projeto: ").strip()
    palavra = input("Digite a palavra a buscar: ").strip()
    encontrados = buscar_arquivos_por_palavra(caminho, palavra)

    print("\nArquivos contendo a palavra:")
    for arquivo in encontrados:
        print(arquivo)
# Out:
# Digite o caminho do projeto:  C:\Users\nonak\AppData\Local
